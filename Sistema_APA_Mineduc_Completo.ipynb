# %% [markdown]
# <a href="https://colab.research.google.com/github/educacionrealamp-ux/sistema-apa/blob/main/Sistema_APA_Mineduc_Completo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==================================================
# 🔹 SISTEMA APA + DUA - CÓDIGO FINAL CORREGIDO 🔹
# ✅ CARGA TODAS LAS DESTREZAS - SIN ERRORES
# ==================================================

# ----------------------
# IMPORTACIONES
# ----------------------
import pandas as pd
import io
from ipywidgets import (
    widgets, Layout, VBox, HBox, HTML, SelectMultiple,
    RadioButtons, Output, Button, FileUpload
)
from IPython.display import display, clear_output, FileLink

# ----------------------
# 📋 BASE DE DATOS: ÁREAS OFICIALES COMPLETAS
# ----------------------
datos_sistema = [
    # ==============================================
    # 🔹 EDUCACIÓN INICIAL (3 - 4 AÑOS)
    # ==============================================
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Inicial (3-4 Años)", "AREA": "Desarrollo Personal y Social", "COLOR_AREA": "#16a085", "OBJETIVO_AREA": "Desarrollar identidad, autonomía y convivencia", "CRITERIO_EVALUACION": "Expresa emociones, necesidades y se relaciona con otros", "DCD": "IPS.1.1.1", "INDICADOR_EVALUACION": "Reconoce su nombre, características y pertenencia", "HABILIDADES": "Identificar, Comunicar", "INSERCIONES": "CS", "AÑO": "1"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Inicial (3-4 Años)", "AREA": "Comunicación y Representación", "COLOR_AREA": "#16a085", "OBJETIVO_AREA": "Usar lenguaje para expresar, comprender y representar el entorno", "CRITERIO_EVALUACION": "Comprende mensajes orales y se expresa con claridad", "DCD": "ICR.1.2.1", "INDICADOR_EVALUACION": "Describe objetos, personas y situaciones cotidianas", "HABILIDADES": "Comunicar, Describir", "INSERCIONES": "CM", "AÑO": "1"},

    # ==============================================
    # 🔸 PREPARATORIA (5 - 6 AÑOS)
    # ==============================================
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔸 Preparatoria (5-6 Años)", "AREA": "Lengua y Literatura", "COLOR_AREA": "#2980b9", "OBJETIVO_AREA": "Comprender y producir textos orales y escritos sencillos", "CRITERIO_EVALUACION": "Expresa ideas, sentimientos y comprende mensajes", "DCD": "LIT.1.1.1", "INDICADOR_EVALUACION": "Lee y escribe palabras y oraciones cortas", "HABILIDADES": "Leer, Escribir, Comprender", "INSERCIONES": "CM", "AÑO": "1"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔸 Preparatoria (5-6 Años)", "AREA": "Matemática", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Resolver problemas sencillos con números, formas y medidas", "CRITERIO_EVALUACION": "Usa números, cuenta, compara y resuelve operaciones básicas", "DCD": "MAT.1.2.3", "INDICADOR_EVALUACION": "Resuelve sumas y restas sencillas, identifica figuras", "HABILIDADES": "Calcular, Identificar, Resolver", "INSERCIONES": "CM", "AÑO": "1"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔸 Preparatoria (5-6 Años)", "AREA": "Ciencias Naturales", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Explorar y conocer seres vivos, entorno y cuidado de la salud", "CRITERIO_EVALUACION": "Identifica características de seres vivos y su entorno", "DCD": "CN.1.3.1", "INDICADOR_EVALUACION": "Clasifica seres vivos y objetos por sus características", "HABILIDADES": "Observar, Clasificar, Cuidar", "INSERCIONES": "CS", "AÑO": "1"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔸 Preparatoria (5-6 Años)", "AREA": "Estudios Sociales", "COLOR_AREA": "#f39c12", "OBJETIVO_AREA": "Conocer su identidad, familia, escuela y comunidad", "CRITERIO_EVALUACION": "Reconoce su pertenencia, normas y valores de convivencia", "DCD": "ES.1.4.1", "INDICADOR_EVALUACION": "Identifica miembros de la familia, roles y espacios cercanos", "HABILIDADES": "Identificar, Reconocer, Convivir", "INSERCIONES": "CS", "AÑO": "1"},

    # ==============================================
    # 🔹 ELEMENTAL (2º - 4º)
    # ==============================================
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Elemental (2º - 4º)", "AREA": "Lengua y Literatura", "COLOR_AREA": "#2980b9", "OBJETIVO_AREA": "Desarrollar competencias comunicativas: leer, escribir, escuchar y hablar", "CRITERIO_EVALUACION": "Interpreta textos, extrae ideas y se expresa con coherencia", "DCD": "LIT.2.1.5", "INDICADOR_EVALUACION": "Identifica idea principal y detalles en textos narrativos", "HABILIDADES": "Analizar, Interpretar, Redactar", "INSERCIONES": "CM", "AÑO": "2"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Elemental (2º - 4º)", "AREA": "Lengua y Literatura", "COLOR_AREA": "#2980b9", "OBJETIVO_AREA": "Desarrollar competencias comunicativas: leer, escribir, escuchar y hablar", "CRITERIO_EVALUACION": "Interpreta textos, extrae ideas y se expresa con coherencia", "DCD": "LIT.2.1.6", "INDICADOR_EVALUACION": "Produce textos breves con coherencia y cohesión", "HABILIDADES": "Redactar, Organizar, Comunicar", "INSERCIONES": "CM", "AÑO": "2"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Elemental (2º - 4º)", "AREA": "Matemática", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Aplicar operaciones, razonamiento y resolución de problemas", "CRITERIO_EVALUACION": "Resuelve operaciones combinadas y problemas de la vida real", "DCD": "MAT.2.2.4", "INDICADOR_EVALUACION": "Resuelve sumas, restas, multiplicaciones y divisiones", "HABILIDADES": "Resolver, Calcular, Aplicar", "INSERCIONES": "CM", "AÑO": "3"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Elemental (2º - 4º)", "AREA": "Matemática", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Aplicar operaciones, razonamiento y resolución de problemas", "CRITERIO_EVALUACION": "Resuelve operaciones combinadas y problemas de la vida real", "DCD": "MAT.2.2.5", "INDICADOR_EVALUACION": "Usa estrategias de cálculo mental y estimación", "HABILIDADES": "Calcular, Estimar, Razonar", "INSERCIONES": "CM", "AÑO": "3"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Elemental (2º - 4º)", "AREA": "Ciencias Naturales", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Comprender procesos naturales, cuerpo humano y cuidado ambiental", "CRITERIO_EVALUACION": "Explica fenómenos, ciclos y funciones básicas", "DCD": "CN.2.3.2", "INDICADOR_EVALUACION": "Describe ciclos de vida, partes de plantas y animales", "HABILIDADES": "Explicar, Observar, Proteger", "INSERCIONES": "CS", "AÑO": "4"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Elemental (2º - 4º)", "AREA": "Ciencias Naturales", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Comprender procesos naturales, cuerpo humano y cuidado ambiental", "CRITERIO_EVALUACION": "Explica fenómenos, ciclos y funciones básicas", "DCD": "CN.2.3.3", "INDICADOR_EVALUACION": "Identifica relaciones entre seres vivos y su entorno", "HABILIDADES": "Relacionar, Observar, Cuidar", "INSERCIONES": "CS", "AÑO": "4"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Elemental (2º - 4º)", "AREA": "Estudios Sociales", "COLOR_AREA": "#f39c12", "OBJETIVO_AREA": "Conocer historia, geografía, símbolos y organización social básica", "CRITERIO_EVALUACION": "Reconoce hechos, lugares y normas de convivencia", "DCD": "ES.2.4.2", "INDICADOR_EVALUACION": "Identifica símbolos patrios, provincias y organización familiar", "HABILIDADES": "Reconocer, Ubicar, Valorar", "INSERCIONES": "ECI", "AÑO": "4"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Elemental (2º - 4º)", "AREA": "Estudios Sociales", "COLOR_AREA": "#f39c12", "OBJETIVO_AREA": "Conocer historia, geografía, símbolos y organización social básica", "CRITERIO_EVALUACION": "Reconoce hechos, lugares y normas de convivencia", "DCD": "ES.2.4.3", "INDICADOR_EVALUACION": "Explica la organización de la comunidad y sus servicios", "HABILIDADES": "Explicar, Conocer, Valorar", "INSERCIONES": "ECI", "AÑO": "4"},
# ==============================================
    # 🔹 MEDIA (5º - 7º)
    # ==============================================
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Media (5º - 7º)", "AREA": "Lengua y Literatura", "COLOR_AREA": "#2980b9", "OBJETIVO_AREA": "Profundizar comprensión lectora, producción escrita y análisis de textos", "CRITERIO_EVALUACION": "Analiza estructura, intención y recursos en diversos textos", "DCD": "LIT.3.1.8", "INDICADOR_EVALUACION": "Identifica estructura narrativa, descripción y argumentación básica", "HABILIDADES": "Interpretar, Analizar, Argumentar", "INSERCIONES": "CM", "AÑO": "6"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Media (5º - 7º)", "AREA": "Lengua y Literatura", "COLOR_AREA": "#2980b9", "OBJETIVO_AREA": "Profundizar comprensión lectora, producción escrita y análisis de textos", "CRITERIO_EVALUACION": "Analiza estructura, intención y recursos en diversos textos", "DCD": "LIT.3.1.9", "INDICADOR_EVALUACION": "Produce textos con diferentes propósitos comunicativos", "HABILIDADES": "Redactar, Planificar, Comunicar", "INSERCIONES": "CM", "AÑO": "6"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Media (5º - 7º)", "AREA": "Matemática", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Desarrollar pensamiento lógico, fracciones, decimales y geometría", "CRITERIO_EVALUACION": "Usa fracciones, decimales y resuelve problemas geométricos", "DCD": "MAT.3.2.7", "INDICADOR_EVALUACION": "Resuelve operaciones con fracciones, decimales y perímetros", "HABILIDADES": "Calcular, Razonar, Resolver", "INSERCIONES": "CM", "AÑO": "7"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Media (5º - 7º)", "AREA": "Matemática", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Desarrollar pensamiento lógico, fracciones, decimales y geometría", "CRITERIO_EVALUACION": "Usa fracciones, decimales y resuelve problemas geométricos", "DCD": "MAT.3.2.8", "INDICADOR_EVALUACION": "Aplica conceptos de área, volumen y ángulos en situaciones reales", "HABILIDADES": "Aplicar, Calcular, Razonar", "INSERCIONES": "CM", "AÑO": "7"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Media (5º - 7º)", "AREA": "Ciencias Naturales", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Entender cuerpo humano, sistemas, materia y energía básica", "CRITERIO_EVALUACION": "Describe funciones, sistemas y cambios de estado", "DCD": "CN.3.3.3", "INDICADOR_EVALUACION": "Explica sistemas digestivo, respiratorio y circulatorio", "HABILIDADES": "Describir, Explicar, Cuidar", "INSERCIONES": "CS", "AÑO": "7"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Media (5º - 7º)", "AREA": "Ciencias Naturales", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Entender cuerpo humano, sistemas, materia y energía básica", "CRITERIO_EVALUACION": "Describe funciones, sistemas y cambios de estado", "DCD": "CN.3.3.4", "INDICADOR_EVALUACION": "Identifica cambios de estado de la materia y fuentes de energía", "HABILIDADES": "Identificar, Explicar, Relacionar", "INSERCIONES": "CS", "AÑO": "7"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Media (5º - 7º)", "AREA": "Estudios Sociales", "COLOR_AREA": "#f39c12", "OBJETIVO_AREA": "Comprender organización del Estado, historia y geografía nacional", "CRITERIO_EVALUACION": "Analiza hechos históricos y organización social", "DCD": "ES.3.4.2", "INDICADOR_EVALUACION": "Explica organización del Estado, poderes y derechos", "HABILIDADES": "Explicar, Analizar, Valorar", "INSERCIONES": "ECI", "AÑO": "5"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Media (5º - 7º)", "AREA": "Estudios Sociales", "COLOR_AREA": "#f39c12", "OBJETIVO_AREA": "Comprender organización del Estado, historia y geografía nacional", "CRITERIO_EVALUACION": "Analiza hechos históricos y organización social", "DCD": "ES.3.4.3", "INDICADOR_EVALUACION": "Ubica regiones geográficas y recursos naturales del país", "HABILIDADES": "Ubicar, Identificar, Valorar", "INSERCIONES": "ECI", "AÑO": "5"},

    # ==============================================
    # 🔹 SUPERIOR (8° - 10°) ✅ 9 ÁREAS COMPLETAS
    # ==============================================
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Superior (8° - 10°)", "AREA": "Lengua y Literatura", "COLOR_AREA": "#2980b9", "OBJETIVO_AREA": "Desarrollar pensamiento crítico, comunicación y análisis literario", "CRITERIO_EVALUACION": "Argumenta, interpreta y produce textos académicos", "DCD": "LIT.4.1.14", "INDICADOR_EVALUACION": "Elabora textos argumentativos, expositivos y analiza obras", "HABILIDADES": "Argumentar, Analizar, Redactar", "INSERCIONES": "CM", "AÑO": "8"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Superior (8° - 10°)", "AREA": "Lengua y Literatura", "COLOR_AREA": "#2980b9", "OBJETIVO_AREA": "Desarrollar pensamiento crítico, comunicación y análisis literario", "CRITERIO_EVALUACION": "Argumenta, interpreta y produce textos académicos", "DCD": "LIT.4.1.15", "INDICADOR_EVALUACION": "Analiza recursos estilísticos y contexto en obras literarias", "HABILIDADES": "Analizar, Interpretar, Valorar", "INSERCIONES": "CM", "AÑO": "8"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Superior (8° - 10°)", "AREA": "Matemática", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Aplicar álgebra, geometría, estadística y probabilidad", "CRITERIO_EVALUACION": "Resuelve ecuaciones, sistemas y problemas matemáticos", "DCD": "MAT.4.2.11", "INDICADOR_EVALUACION": "Resuelve ecuaciones, funciones y análisis estadístico", "HABILIDADES": "Resolver, Modelar, Calcular", "INSERCIONES": "CM", "AÑO": "8"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Superior (8° - 10°)", "AREA": "Matemática", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Aplicar álgebra, geometría, estadística y probabilidad", "CRITERIO_EVALUACION": "Resuelve ecuaciones, sistemas y problemas matemáticos", "DCD": "MAT.4.2.12", "INDICADOR_EVALUACION": "Aplica probabilidad y estadística para interpretar datos", "HABILIDADES": "Interpretar, Calcular, Aplicar", "INSERCIONES": "CM", "AÑO": "8"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Superior (8° - 10°)", "AREA": "Ciencias Naturales", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Comprender física, química, biología, geología y cuidado ambiental", "CRITERIO_EVALUACION": "Explica fenómenos, leyes científicas y procesos naturales", "DCD": "CN.4.3.5", "INDICADOR_EVALUACION": "Explica energía, materia, fuerzas y seres vivos", "HABILIDADES": "Explicar, Investigar, Relacionar", "INSERCIONES": "CS", "AÑO": "8"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Superior (8° - 10°)", "AREA": "Ciencias Naturales", "COLOR_AREA": "#27ae60", "OBJETIVO_AREA": "Comprender física, química, biología, geología y cuidado ambiental", "CRITERIO_EVALUACION": "Explica fenómenos, leyes científicas y procesos naturales", "DCD": "CN.4.3.6", "INDICADOR_EVALUACION": "Analiza impacto de actividades humanas en el ambiente", "HABILIDADES": "Analizar, Cuidar, Proteger", "INSERCIONES": "CS", "AÑO": "8"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Superior (8° - 10°)", "AREA": "Estudios Sociales", "COLOR_AREA": "#f39c12", "OBJETIVO_AREA": "Analizar historia, geografía, ciudadanía y realidad nacional", "CRITERIO_EVALUACION": "Interpreta procesos históricos, sociales y territoriales", "DCD": "ES.4.4.5", "INDICADOR_EVALUACION": "Analiza independencia, Estado, derechos y organización", "HABILIDADES": "Analizar, Interpretar, Ubicar", "INSERCIONES": "ECI", "AÑO": "8"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Superior (8° - 10°)", "AREA": "Estudios Sociales", "COLOR_AREA": "#f39c12", "OBJETIVO_AREA": "Analizar historia, geografía, ciudadanía y realidad nacional", "CRITERIO_EVALUACION": "Interpreta procesos históricos, sociales y territoriales", "DCD": "ES.4.4.6", "INDICADOR_EVALUACION": "Valora diversidad cultural y derechos humanos", "HABILIDADES": "Valorar, Respetar, Convivir", "INSERCIONES": "ECI", "AÑO": "8"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Superior (8° - 10°)", "AREA": "Educación Física", "COLOR_AREA": "#e74c3c", "OBJETIVO_AREA": "Desarrollar motricidad, salud, deporte y valores", "CRITERIO_EVALUACION": "Practica actividades físicas, deportes y trabajo en equipo", "DCD": "EF.4.7.2", "INDICADOR_EVALUACION": "Aplica reglas, cooperación y hábitos saludables", "HABILIDADES": "Practicar, Cooperar, Respetar", "INSERCIONES": "CS", "AÑO": "8"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Superior (8° - 10°)", "AREA": "Educación Cultural y Artística", "COLOR_AREA": "#9b59b6", "OBJETIVO_AREA": "Valorar, crear y expresarse con lenguajes artísticos", "CRITERIO_EVALUACION": "Reconoce, crea y valora patrimonio y expresiones culturales", "DCD": "ECA.4.8.3", "INDICADOR_EVALUACION": "Elabora producciones artísticas con intención comunicativa", "HABILIDADES": "Crear, Valorar, Expresar", "INSERCIONES": "IC.05", "AÑO": "8"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Superior (8° - 10°)", "AREA": "Inglés", "COLOR_AREA": "#3498db", "OBJETIVO_AREA": "Comunicarse en idioma extranjero en contextos cotidianos y académicos", "CRITERIO_EVALUACION": "Comprende y produce mensajes orales y escritos básicos", "DCD": "ING.4.9.1", "INDICADOR_EVALUACION": "Usa vocabulario y estructuras para comunicarse", "HABILIDADES": "Comunicar, Comprender", "INSERCIONES": "CM", "AÑO": "8"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Superior (8° - 10°)", "AREA": "Educación para la Ciudadanía", "COLOR_AREA": "#1abc9c", "OBJETIVO_AREA": "Ejercer derechos, deberes, democracia y convivencia", "CRITERIO_EVALUACION": "Participa, respeta y defiende derechos y deberes", "DCD": "EC.4.10.2", "INDICADOR_EVALUACION": "Reconoce mecanismos de participación y deberes ciudadanos", "HABILIDADES": "Participar, Respetar, Convivir", "INSERCIONES": "ECI", "AÑO": "8"},
    {"NIVEL": "Educación General Básica", "SUBNIVEL": "🔹 Superior (8° - 10°)", "AREA": "Emprendimiento y Gestión", "COLOR_AREA": "#f1c40f", "OBJETIVO_AREA": "Desarrollar iniciativa, proyectos y responsabilidad social", "CRITERIO_EVALUACION": "Planifica, ejecuta y evalúa proyectos productivos", "DCD": "EG.4.11.1", "INDICADOR_EVALUACION": "Diseña proyectos con planificación y trabajo colaborativo", "HABILIDADES": "Planificar, Ejecutar, Evaluar", "INSERCIONES": "CS", "AÑO": "8"},

    # ==============================================
    # 🟣 BACHILLERATO GENERAL UNIFICADO
    # ==============================================
    {"NIVEL": "Bachillerato General Unificado", "SUBNIVEL": "🟣 Bachillerato General Unificado", "AREA": "Lengua y Literatura", "COLOR_AREA": "#8e44ad", "OBJETIVO_AREA": "Interpretar textos complejos y analizar obras literarias", "CRITERIO_EVALUACION": "Analiza y valora obras literarias y su contexto", "DCD": "LIT.BG.2.1", "INDICADOR_EVALUACION": "Analiza recursos estilísticos y temáticos en obras", "HABILIDADES": "Valorar, Interpretar", "INSERCIONES": "D", "AÑO": "1"},
    {"NIVEL": "Bachillerato General Unificado", "SUBNIVEL": "🟣 Bachillerato General Unificado", "AREA": "Lengua y Literatura", "COLOR_AREA": "#8e44ad", "OBJETIVO_AREA": "Interpretar textos complejos y analizar obras literarias", "CRITERIO_EVALUACION": "Analiza y valora obras literarias y su contexto", "DCD": "LIT.BG.2.2", "INDICADOR_EVALUACION": "Produce textos académicos y argumentativos", "HABILIDADES": "Redactar, Argumentar", "INSERCIONES": "D", "AÑO": "1"},
    {"NIVEL": "Bachillerato General Unificado", "SUBNIVEL": "🟣 Bachillerato General Unificado", "AREA": "Matemática", "COLOR_AREA": "#f39c12", "OBJETIVO_AREA": "Modelar fenómenos con lenguaje matemático", "CRITERIO_EVALUACION": "Aplica funciones y modelos matemáticos a situaciones reales", "DCD": "MAT.BG.3.4", "INDICADOR_EVALUACION": "Resuelve problemas usando funciones lineales, cuadráticas y exponenciales", "HABILIDADES": "Modelar, Resolver", "INSERCIONES": "ECI", "AÑO": "2"},
    {"NIVEL": "Bachillerato General Unificado", "SUBNIVEL": "🟣 Bachillerato General Unificado", "AREA": "Matemática", "COLOR_AREA": "#f39c12", "OBJETIVO_AREA": "Modelar fenómenos con lenguaje matemático", "CRITERIO_EVALUACION": "Aplica funciones y modelos matemáticos a situaciones reales", "DCD": "MAT.BG.3.5", "INDICADOR_EVALUACION": "Usa estadística y probabilidad para análisis de datos", "HABILIDADES": "Analizar, Calcular", "INSERCIONES": "ECI", "AÑO": "2"}
]

# 📊 PROCESAMIENTO: CARGA CORRECTA Y LIMPIA
df_base = pd.DataFrame(datos_sistema)
df_base['SUBNIVEL'] = df_base['SUBNIVEL'].str.strip()
df_base['AREA'] = df_base['AREA'].str.strip()
df_base['AÑO'] = df_base['AÑO'].astype(str).str.strip()

datos_por_subnivel = {}
for sub in sorted(df_base['SUBNIVEL'].unique()):
    temp = df_base[df_base['SUBNIVEL'] == sub]
    grados = sorted(temp['AÑO'].dropna().unique().tolist())
    areas_unicas = sorted(temp['AREA'].dropna().unique().tolist())
    datos_por_subnivel[sub] = {'grados': grados, 'areas': areas_unicas}

# ----------------------
# 📘 ENFOQUE DUA Y RECURSOS
# ----------------------
dua = [
    {"nombre": "Representación", "color": "#2980b9", "desc": "Presentar la información de distintas formas: visual, auditiva, táctil."},
    {"nombre": "Acción y Expresión", "color": "#27ae60", "desc": "Ofrecer diversas formas para que el estudiante demuestre lo aprendido."},
    {"nombre": "Motivación", "color": "#8e44ad", "desc": "Fomentar el interés, la participación y la autonomía del aprendizaje."}
]

metodologias = [
    "Aprendizaje Basado en Proyectos", "Aprendizaje Cooperativo",
    "Aprendizaje Basado en Problemas", "Gamificación", "Aula Invertida",
    "Aprendizaje Servicio", "Investigación Acción", "Estudio de Casos",
    "Aprendizaje Significativo", "Enseñanza Diferenciada"
]

recursos_didacticos = [
    "Libro de texto", "Guía didáctica", "Material audiovisual", "Software educativo",
    "Material concreto / manipulativo", "Fichas de trabajo", "Juegos educativos",
    "Pizarras interactivas", "Biblioteca del aula", "Material impreso", "Cuadernos de trabajo"
]

evaluacion_tipos = [
    "Diagnóstica", "Formativa", "Sumativa", "Autoevaluación", "Coevaluación", "Heteroevaluación"
]

# ----------------------
# 🧩 COMPONENTES REUTILIZABLES
# ----------------------
def generar_lista_destrezas(datos_filtrados):
    if datos_filtrados.empty:
        return HTML("<p style='color:red; text-align:center; padding:10px;'>❌ No hay destrezas para esta selección</p>")

    opciones = []
    iconos_insercion = {"CM":"🧠", "CS":"🤝", "D":"🚀", "ECI":"⚖️", "DS":"📊", "ES":"❤️", "SEG":"🛡️", "EF":"💰", "IC.05":"🎨"}

    for _, fila in datos_filtrados.iterrows():
        icono = iconos_insercion.get(str(fila['INSERCIONES']), "📌")
        texto = f"{icono} <b>{fila['DCD']}</b> | {fila['INDICADOR_EVALUACION']}"
        opciones.append(texto)

    return SelectMultiple(
        options=opciones,
        description='📋 Destrezas:',
        layout=Layout(width='100%', height='220px', margin='5px 0'),
        style={'description_width': 'initial'}
    )

def bloque_planificacion_completa(datos_filtrados, color_principal="#27ae60"):
    # Sección DUA
    seccion_dua = HBox([
        VBox([
            HTML(f"<div style='background:{dua[0]['color']}; color:white; padding:8px; border-radius:5px; font-weight:bold; text-align:center;'>{dua[0]['nombre']}</div>"),
            HTML(f"<p style='padding:8px; text-align:justify; font-size:13px;'>{dua[0]['desc']}</p>")
        ], layout=Layout(width='31%', border='1px solid #ddd', border_radius='8px', padding='5px')),
        VBox([
            HTML(f"<div style='background:{dua[1]['color']}; color:white; padding:8px; border-radius:5px; font-weight:bold; text-align:center;'>{dua[1]['nombre']}</div>"),
            HTML(f"<p style='padding:8px; text-align:justify; font-size:13px;'>{dua[1]['desc']}</p>")
        ], layout=Layout(width='31%', border='1px solid #ddd', border_radius='8px', padding='5px')),
        VBox([
            HTML(f"<div style='background:{dua[2]['color']}; color:white; padding:8px; border-radius:5px; font-weight:bold; text-align:center;'>{dua[2]['nombre']}</div>"),
            HTML(f"<p style='padding:8px; text-align:justify; font-size:13px;'>{dua[2]['desc']}</p>")
        ], layout=Layout(width='31%', border='1px solid #ddd', border_radius='8px', padding='5px'))
    ], layout=Layout(justify_content='space-between', margin='10px 0'))

    # Sección Metodología y Recursos
    seccion_metodologia = VBox([
        HTML(f"<h3 style='color:{color_principal}; margin:15px 0 5px 0;'>🔧 METODOLOGÍA Y RECURSOS</h3><hr style='border-color:{color_principal};'>"),

        HTML("<b>📘 Metodologías activas recomendadas:</b>"),
        SelectMultiple(options=metodologias, value=[metodologias[0]], layout=Layout(width='100%', height='120px', margin='5px 0')),

        HTML("<br><b>📚 Recursos Didácticos:</b>"),
        SelectMultiple(options=recursos_didacticos, value=[recursos_didacticos[0], recursos_didacticos[1]], layout=Layout(width='100%', height='120px', margin='5px 0')),

        HTML("<br><b>✅ Tipo de Evaluación:</b>"),
        RadioButtons(options=evaluacion_tipos, value='Formativa', layout=Layout(margin='5px 0'))
    ])

    # Sección Selección de Destrezas
    seccion_destrezas = VBox([
        HTML(f"<h3 style='color:{color_principal}; margin:15px 0 5px 0;'>🎯 SELECCIÓN DE DESTREZAS CON CRITERIOS</h3><hr style='border-color:{color_principal};'>"),
        generar_lista_destrezas(datos_filtrados),

        HTML("<br><b>📌 Objetivo del Área:</b>"),
        widgets.Textarea(value=str(datos_filtrados['OBJETIVO_AREA'].iloc[0]) if not datos_filtrados.empty else "", layout=Layout(width='100%', height='60px')),

        HTML("<br><b>⚖️ Criterio de Evaluación:</b>"),
        widgets.Textarea(value=str(datos_filtrados['CRITERIO_EVALUACION'].iloc[0]) if not datos_filtrados.empty else "", layout=Layout(width='100%', height='60px'))
    ])

    return VBox([seccion_dua, seccion_destrezas, seccion_metodologia], layout=Layout(padding='10px'))

# ----------------------
# FUNCIÓN CARGA DE ARCHIVO
# ----------------------
def cargar_y_completar_archivo(contenido, nombre_archivo):
    try:
        if nombre_archivo.endswith('.csv'):
            df_usuario = pd.read_csv(io.BytesIO(contenido))
        else:
            df_usuario = pd.read_excel(io.BytesIO(contenido))

        df_completo = pd.merge(df_usuario, df_base, on=['SUBNIVEL', 'AREA', 'AÑO'], how='left')

        output = io.BytesIO()
        with pd.ExcelWriter(output, engine='xlsxwriter') as writer:
            df_completo.to_excel(writer, index=False, sheet_name='Planificación Completa')
        archivo_listo = output.getvalue()

        return True, df_completo, archivo_listo
    except Exception as e:
        return False, str(e), None

# ----------------------
# INTERFAZ PRINCIPAL
# ----------------------
zona = Output()

def cambiar_vista(evento):
    with zona:
        clear_output(wait=True)
        if evento['new'] == 'INICIO':
            display(HTML("""
            <div style='text-align:center; padding:30px; background:linear-gradient(135deg,#f0f4f8,#e2e8f0); border-radius:20px;'>
                <h2 style='color:#2c3e50;'>¡BIENVENIDO A APA + DUA!</h2>
                <p style='font-size:16px; color:#34495e; max-width:700px; margin:auto;'>
                Sistema Oficial de Planificación Educativa - Mineduc<br>
                Optimización de Tiempo | Carga y Completa Automáticamente
                </p>
            </div>
            """))

        elif evento['new'] == '👤 DOCENTE INDEPENDIENTE':
            nombre = widgets.Text(value='', description='👤 Nombre:', style={'description_width': 'initial'}, placeholder='Ingrese su nombre completo')
            subnivel = widgets.Dropdown(options=list(datos_por_subnivel.keys()), description='📂 Subnivel:', layout=Layout(width='48%'))
            grado = widgets.Dropdown(options=['TODOS'], description='🎓 Año:', layout=Layout(width='48%'))
            area = widgets.Dropdown(options=['TODOS'], description='📚 Área:', layout=Layout(width='100%', margin='10px 0'))

            def actualizar_listas(change):
                s = change['new']
                if s in datos_por_subnivel:
                    grado.options = ['TODOS'] + datos_por_subnivel[s]['grados']
                    grado.value = 'TODOS'
                    area.options = ['TODOS'] + datos_por_subnivel[s]['areas']
                    area.value = 'TODOS'
            subnivel.observe(actualizar_listas, names='value')

            cargador = FileUpload(accept='.xlsx,.csv', multiple=False)
            salida_archivo = Output()
            contenido_planificacion = Output()

            # ✅ FILTRO CORREGIDO: CARGA TODAS LAS DESTREZAS
            def procesar_seleccion(b):
                with contenido_planificacion:
                    clear_output()
                    filtro = df_base.copy()
                    # 🔹 FILTRO EXACTO Y COMPLETO
                    if subnivel.value:
                        filtro = filtro[filtro['SUBNIVEL'].str.strip() == subnivel.value.strip()]
                    if grado.value != 'TODOS':
                        filtro = filtro[filtro['AÑO'].str.strip() == grado.value.strip()]
                    if area.value and area.value != 'TODOS':
                        filtro = filtro[filtro['AREA'].str.strip() == area.value.strip()]

                    color = filtro['COLOR_AREA'].iloc[0] if not filtro.empty else '#95a5a6'
                    display(bloque_planificacion_completa(filtro, color))

            boton_cargar = Button(description="✅ CARGAR Y VER PLANIFICACIÓN", button_style='success', layout=Layout(width='100%', height='40px', margin='10px 0'))
            boton_cargar.on_click(procesar_seleccion)

            def procesar_archivo(change):
                with salida_archivo:
                    clear_output()
                    if cargador.value:
                        nombre_archivo = next(iter(cargador.value))
                        contenido = cargador.value[nombre_archivo]['content']
                        exito, datos, archivo = cargar_y_completar_archivo(contenido, nombre_archivo)
                        if exito:
                            display(HTML("<p style='color:green; font-weight:bold;'>✅ ARCHIVO COMPLETADO AUTOMÁTICAMENTE</p>"))
                            with open('Planificacion_Lista_Independiente.xlsx', 'wb') as f:
                                f.write(archivo)
                            display(FileLink('Planificacion_Lista_Independiente.xlsx'))
                        else:
                            display(HTML(f"<p style='color:red;'>❌ Error: {datos}</p>"))
            cargador.observe(procesar_archivo, names='value')

            display(VBox([
                nombre,
                HBox([subnivel, grado], layout=Layout(width='100%', justify_content='space-between')),
                area,
                boton_cargar,
                HTML("<br><b>📤 O CARGA TU ARCHIVO (Excel/CSV):</b>"),
                cargador, salida_archivo,
                contenido_planificacion
            ], layout=Layout(width='90%', margin='0 auto', padding='15px', border='2px solid #27ae60', border_radius='12px')))

        elif evento['new'] == '🏫 DOCENTE INSTITUCIONAL':
            institucion = widgets.Text(value='', description='🏫 Institución:', style={'description_width': 'initial'}, placeholder='Nombre de la institución educativa')
            subnivel = widgets.Dropdown(options=list(datos_por_subnivel.keys()), description='📂 Subnivel:', layout=Layout(width='48%'))
            grado = widgets.Dropdown(options=['TODOS'], description='🎓 Año:', layout=Layout(width='48%'))
            area = widgets.Dropdown(options=['TODOS'], description='📚 Área:', layout=Layout(width='100%', margin='10px 0'))

            def actualizar_listas_inst(change):
                s = change['new']
                if s in datos_por_subnivel:
                    grado.options = ['TODOS'] + datos_por_subnivel[s]['grados']
                    grado.value = 'TODOS'
                    area.options = ['TODOS'] + datos_por_subnivel[s]['areas']
                    area.value = 'TODOS'
            subnivel.observe(actualizar_listas_inst, names='value')

            cargador_inst = FileUpload(accept='.xlsx,.csv', multiple=False)
            salida_archivo_inst = Output()
            contenido_planificacion_inst = Output()

            # ✅ FILTRO CORREGIDO: CARGA TODAS LAS DESTREZAS
            def procesar_seleccion_inst(b):
                with contenido_planificacion_inst:
                    clear_output()
                    filtro = df_base.copy()
                    # 🔹 FILTRO EXACTO Y COMPLETO
                    if subnivel.value:
                        filtro = filtro[filtro['SUBNIVEL'].str.strip() == subnivel.value.strip()]
                    if grado.value != 'TODOS':
                        filtro = filtro[filtro['AÑO'].str.strip() == grado.value.strip()]
                    if area.value and area.value != 'TODOS':
                        filtro = filtro[filtro['AREA'].str.strip() == area.value.strip()]

                    color = filtro['COLOR_AREA'].iloc[0] if not filtro.empty else '#95a5a6'
                    display(bloque_planificacion_completa(filtro, color))

            boton_cargar_inst = Button(description="✅ CARGAR Y VER PLANIFICACIÓN", button_style='info', layout=Layout(width='100%', height='40px', margin='10px 0'))
            boton_cargar_inst.on_click(procesar_seleccion_inst)

            def procesar_archivo_inst(change):
                with salida_archivo_inst:
                    clear_output()
                    if cargador_inst.value:
                        nombre_archivo = next(iter(cargador_inst.value))
                        contenido = cargador_inst.value[nombre_archivo]['content']
                        exito, datos, archivo = cargar_y_completar_archivo(contenido, nombre_archivo)
                        if exito:
                            display(HTML("<p style='color:green; font-weight:bold;'>✅ ARCHIVO COMPLETADO AUTOMÁTICAMENTE</p>"))
                            with open('Planificacion_Lista_Institucional.xlsx', 'wb') as f:
                                f.write(archivo)
                            display(FileLink('Planificacion_Lista_Institucional.xlsx'))
                        else:
                            display(HTML(f"<p style='color:red;'>❌ Error: {datos}</p>"))
            cargador_inst.observe(procesar_archivo_inst, names='value')

            display(VBox([
                institucion,
                HBox([subnivel, grado], layout=Layout(width='100%', justify_content='space-between')),
                area,
                boton_cargar_inst,
                HTML("<br><b>📤 O CARGA TU ARCHIVO (Excel/CSV):</b>"),
                cargador_inst, salida_archivo_inst,
                contenido_planificacion_inst
            ], layout=Layout(width='90%', margin='0 auto', padding='15px', border='2px solid #2980b9', border_radius='12px')))


# ----------------------
# 🚀 EJECUCIÓN FINAL (SIN ERRORES)
# ----------------------
menu = widgets.ToggleButtons(
    options=['INICIO', '👤 DOCENTE INDEPENDIENTE', '🏫 DOCENTE INSTITUCIONAL'],
    value='INICIO',
    description='MENÚ PRINCIPAL:',
    layout=Layout(width='100%', padding='10px'),
    style={'button_width': 'auto', 'font_weight': 'bold'}
)

menu.observe(cambiar_vista, names='value')

display(VBox([menu, zona], layout=Layout(width='98%', margin='0 auto')))

# Cargar vista inicial
cambiar_vista({'new': 'INICIO'})
